# %%
# %load_ext autoreload
# %autoreload 2

from lrp import *
from lrp.data import Data
from lrp import read_mnist
import os
from lrp.evaluate_rule import HeatmapEval
from lrp import utils
import os
from lrp.generator import *
# Out:
# /home/niels/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
mnist = read_mnist.read_data_sets("{}/datasets/mnist".format(os.environ["TF_PROJECTS"]), one_hot=True)
X_train = mnist.train.images[:100]
X_test = mnist.train.images[100:105]
Y_test = mnist.train.labels[100:105]

s_c = np.ones([28, 28])
s_c[13:15, 13:15] = 0
s_c = s_c.flatten()

m_c = np.ones([28, 28])
m_c[11:17, 11:17] = 0
m_c = m_c.flatten()

m_l = np.ones([28, 28])
m_l[4:14, 8:20] = 0
m_l = m_l.flatten()
# Out:
# Extracting /home/niels/Dokumente/Informatik/bachelor/tensorflow/datasets/mnist/train-images-idx3-ubyte.gz
# Extracting /home/niels/Dokumente/Informatik/bachelor/tensorflow/datasets/mnist/train-labels-idx1-ubyte.gz
# Extracting /home/niels/Dokumente/Informatik/bachelor/tensorflow/datasets/mnist/t10k-images-idx3-ubyte.gz
# Extracting /home/niels/Dokumente/Informatik/bachelor/tensorflow/datasets/mnist/t10k-labels-idx1-ubyte.gz

# %%
data = Data(X=mnist.train.images, y=mnist.train.labels,
                X_val=mnist.validation.images, y_val=mnist.validation.labels,
                X_test=mnist.test.images, y_test=mnist.test.labels)
fcn = Network([Format(), FirstLinear(784), ReLU(), NextLinear(10)], data.X, data.y_)
cnn = Network([Format(), FirstConvolution([5, 5, 1, 32]), ReLU(), Pooling(),
               NextConvolution([5, 5, 32, 64]), ReLU(), Pooling(),
               NextLinear(1024), ReLU(),
               NextLinear(10)],
               data.X, data.y_)

sess = tf.Session()
fcn.set_session(sess)
cnn.set_session(sess)
sess.run(tf.global_variables_initializer())

fcn.fit(data, lambda i, val_acc: max([0]+val_acc)<=0.95)
cnn.fit(data, lambda i, val_acc: max([0]+val_acc)<=0.95)
# Out:
# Network layer mappings: (?, 784)
# -> (?, 784)
# -> (?, 784)
# -> (?, 10)
# Network layer mappings: (?, 784)
# -> (?, 24, 24, 32)
# -> (?, 24, 24, 32)
# -> (?, 12, 12, 32)
# -> (?, 8, 8, 64)
# -> (?, 8, 8, 64)
# -> (?, 4, 4, 64)
# -> (?, 1024)
# -> (?, 1024)
# -> (?, 10)
# Train step  0 :  0.1542
# Train step  50 :  0.8538
# Train step  100 :  0.8834
# Train step  150 :  0.8876
# Train step  200 :  0.8966
# Train step  250 :  0.9204
# Train step  300 :  0.9276
# Train step  350 :  0.9104
# Train step  400 :  0.9272
# Train step  450 :  0.9404
# Train step  500 :  0.9402
# Train step  550 :  0.9304
# Train step  600 :  0.942
# Train step  650 :  0.9314
# Train step  700 :  0.9406
# Train step  750 :  0.9548
# INFO:tensorflow:Restoring parameters from .temp/69b4d/model.ckpt
# Training finished with validation accuracy: 0.9548
# Train step  0 :  0.116
# Train step  50 :  0.9026
# Train step  100 :  0.9422
# Train step  150 :  0.9566
# INFO:tensorflow:Restoring parameters from .temp/bc03b/model.ckpt
# Training finished with validation accuracy: 0.9566
# [0.116, 0.9026, 0.9422, 0.9566]

# %%
gauss_gen = GaussianGenerator(X_train)
stupid_gen = StupidGenerator(X_train)

def add_filter(image_, f):
    image = np.array(image_)
    #image = np.array(f)
    filtered_image = np.zeros([784, 3])
    filtered_image[:,0] = image*0.8
    filtered_image[:,1] = image*0.8
    filtered_image[:,2] = image*0.8
    filtered_image[:,0][f==0] += 0.2
    filtered_image[:,1][f!=0] += 0.2
    filtered_image =  np.reshape(filtered_image, [28, 28, 3])
    return filtered_image

def abs_loss(y, p, labels):
    print("correct scores", np.sum(y*labels, axis=1))
    
    return np.mean(y*Y_test - p*Y_test)

for image_id, image_ in enumerate(X_test):
    # show image with all filters + relevance
    for filter_id, f in enumerate([s_c, m_c, m_l]):
        filtered_image =  add_filter(image_, f)
        plt.subplot(3, 3, filter_id+1)
        plt.imshow(filtered_image)
        
        for g_id, generator in enumerate([gauss_gen, stupid_gen]):
            cnn_rel = cnn.generator_relevance(image_[None,...], f, generator, abs_loss)
            fcn_rel = fcn.generator_relevance(image_[None,...], f, generator, abs_loss)
            translated = add_filter(generator(image_[None,...], f), f*0+1)
            plt.subplot(3, 3, filter_id+4+3*g_id)
            plt.tight_layout()
            plt.imshow(translated)
            plt.title("fcn: {} / cnn: {}".format(fcn_rel, cnn_rel))
         
    plt.show("{}.png".format(image_id))
    plt.clf()
# Out:
# cov (784, 784)
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.014609518051147461
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.00784658432006836
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.009452524185180665
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.010951881408691405
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.001809988021850586
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.007473335266113281
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.00027005195617675783
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.005644540786743164
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.012284097671508789
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.011177558898925782
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.011155261993408203
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.007155351638793946
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.007377529144287109
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.02211129665374756
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.025507121086120604
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.011753840446472168
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.00425351619720459
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.006091532707214356
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.01614264965057373
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.008614029884338379
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.005000324249267578
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.0016457176208496095
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.001530027389526367
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.0018611717224121093
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.004148426055908203
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.0067193603515625
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.002274503707885742
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.0023250579833984375
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.0026633453369140623
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.0034090518951416016
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.04139036893844605
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.036182794570922855
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.029859418869018554
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.023365440368652343
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.026422061920166016
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.04281728267669678
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.04224280595779419
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.02405587673187256
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.027667446136474608
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# correct scores (5,)
# loss 0.03167686223983765
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.15669113636016846
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.05114219665527344
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.08751003861427308
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.017298583984375
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.07933669567108154
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.05428757667541504
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.07028654098510742
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.1441371989250183
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.10559369087219238
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.07199371814727783
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.11449698448181152
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.03751400470733643
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.09976874828338624
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.05816735625267029
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.09920560002326965
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.14115270972251892
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.06909108638763428
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.12042228758335113
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.11973173826932908
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.037036398351192476
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.04074712991714478
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.003670215606689453
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.02227900505065918
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.028418467044830323
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.04223230600357056
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.056289386749267575
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss -0.0024483799934387207
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.018725886344909667
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.007561774253845215
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.027869713306427003
# correct scores [  7.47849894 -13.43138599  -9.16131401  -5.54069948  -5.54069948]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.14314672946929932
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.13890786409378053
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.13615614652633667
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.09969548463821411
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.14101470589637757
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.09849367380142211
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.12301377773284912
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.13186922907829285
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.1567434060573578
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# y.shape (1, 10)
# y*Y_test (5, 10)
# correct scores (5,)
# loss 0.1358843243122101
# correct scores [  8.05627155 -12.30839157  -3.02451706  -8.97881985  -8.97881985]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-1395c279a12c> in <module>()
#      34             fcn_rel = fcn.generator_relevance(image_[None,...], f, generator, abs_loss)
#      35             translated = add_filter(generator(image_[None,...], f), f*0+1)
# ---> 36             plt.subplot(3, 3, filter_id+4+3*g_id)
#      37             plt.tight_layout()
#      38             plt.imshow(translated)
#
# /home/niels/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# /home/niels/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# /home/niels/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      75
#      76         # _axes_class is set in the subplot_class_factory
# ---> 77         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      78         # add a layout box to this, for both the full axis, and the poss
#      79         # of the axis.  We need both because the axes may become smaller
#
# /home/niels/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     486             self._position = mtransforms.Bbox.from_bounds(*rect)
#     487         if self._position.width < 0 or self._position.height < 0:
# --> 488             raise ValueError('Width and height specified must be non-negative')
#     489         self._originalPosition = self._position.frozen()
#     490         # self.set_axes(self)
#
# ValueError: Width and height specified must be non-negative
